# %% [markdown]
# Start: 2/21/2025
# End: ???
#
# Learning ML through Projects.
#
# Brainrot brain can't handle courses and books without applications

# %%
# Packages
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = load_iris(as_frame= True)

# %%
# The feature data
X = data.data

# %%
# The target labels
y = data.target

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
# feature names
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# target names
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# data.target_names[y]
# Out:
# np.str_('setosa')

# %%
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
X.corr()
# Out:
#                    sepal length (cm)  ...  petal width (cm)
# sepal length (cm)           1.000000  ...          0.817941
# sepal width (cm)           -0.117570  ...         -0.366126
# petal length (cm)           0.871754  ...          0.962865
# petal width (cm)            0.817941  ...          1.000000
#
# [4 rows x 4 columns]

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
X.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(X, figsize=(12, 8))
plt.show()

# %%
sns.histplot(X["petal length (cm)"], bins = 30)
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='Count'>

# %%
sns.histplot(X["petal width (cm)"], bins = 30)
# Out:
# <Axes: xlabel='petal width (cm)', ylabel='Count'>

# %%
sns.histplot(X["sepal length (cm)"], bins = 30)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.histplot(X["sepal width (cm)"], bins = 30)
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.33, random_state= 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
basic_model_lr = LogisticRegression(random_state= 0)

# %%
basic_model_lr = basic_model_lr.fit(X_train, y_train)

# %%
predictions = basic_model_lr.predict(X_test)

# %%
(predictions == y_test).sum()
# Out:
# np.int64(50)

# %%
predictions.shape
# Out:
# (50,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors= 3, )

# %%
knn_model = knn_model.fit(X_train, y_train)

# %%
predictions = knn_model.predict(X_test)

# %%
sum(predictions == y_test)
# Out:
# 49
